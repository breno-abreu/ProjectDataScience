# %%
import math
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Casos de COVID-19 em Curitiba
#
# Relatório contendo as informações sobre o número de casos de COVID-19 no município de Curitiba.

# %% [markdown]
# ### Dicionário de dados de casos de COVID-19

# %%
df_casos_dic = pd.read_csv('./data/casos/2022-02-01_Dicionario_de_Dados-Casos_de_COVID.csv', sep=';', encoding='latin-1')
df_casos_dic
# Out:
#    Nome do Campo                                          Descrição
# 0  DATA INCLUSÃO  Data em que caso de COVID foi incluído na base...
# 1  CLASSIFICAÇÃO          Informa se o caso do COVID foi confirmado
# 2          IDADE  Idade do paciente no momento da notificação do...
# 3           SEXO                                   Sexo do Paciente
# 4         BAIRRO  Informa o Bairro de residência do paciente no ...
# 5       DISTRITO  Informa o Distrito Sanitário de residência do ...
# 6  DATA DO ÓBITO                        Data em que ocorreu o óbito
# 7   ENCERRAMENTO  Informa a conclusão final do caso de COVID se ...

# %% [markdown]
# ### Base de dados de casos de COVID-19

# %%
df_casos_base = pd.read_csv('./data/casos/2023-04-05_Casos_Covid_19_-_Base_de_Dados.csv', sep=';', encoding='latin-1')
df_casos_base
# Out:
#        DATA INCLUSÃO/ NOTIFICAÇÃO CLASSIFICAÇÃO FINAL  IDADE (anos) SEXO  \
# 0                      11/03/2020          CONFIRMADO            54    M
# 1                      12/03/2020          CONFIRMADO            15    M
# 2                      12/03/2020          CONFIRMADO            43    M
# 3                      12/03/2020          CONFIRMADO            25    F
# 4                      12/03/2020          CONFIRMADO            58    M
# ...                           ...                 ...           ...  ...
# 587302                 04/04/2023          CONFIRMADO            57    M
# 587303                 04/04/2023          CONFIRMADO            11    F
# 587304                 04/04/2023          CONFIRMADO            13    M
# 587305                 04/04/2023          CONFIRMADO            82    F
# 587306                 04/04/2023          CONFIRMADO            65    F
#
#                 BAIRRO DISTRITO RESIDÊNCIA INTERNADO (SIM/NÃO)  \
# ...

# %% [markdown]
# ## Censo COVID-19 consolidado
#
# Relatório contendo os dados de leitos de UTI e de Enfermaria, adulto e pediatria, disponibilizados pela rede de Hospitais para os atendimentos de pacientes com diagnóstico de COVID-19.

# %% [markdown]
# ### Dicionário de dados Censo COVID-19

# %%
df_censo_dic = pd.read_csv('./data/censo/2022-07-01_Censo_Covid19_-_Dicionario_de_Dados.csv', sep=';', encoding='latin-1')
df_censo_dic
# Out:
#                                        Nome do Campo  \
# 0                                          HOSPITAL
# 1  Casos suspeitos e prováveis  Enfermaria adulto...
# 2  Casos confirmados COVID Enfermaria  Adulto e P...
# 3  Total de internados em leitos de Enfermaria pr...
# 4  Nº de pacientes COVID positivo internados em U...
#
#                                            Descrição
# 0  Hospitas da Rede Credenciada ao SUS para atend...
# 1  Número de pacientes internados com provável di...
# 2  Número de pacientes internados com diagnóstico...
# 3  Número total de pacientes internados nos leito...
# 4  Número de pacientes internados com diagnóstico...

# %% [markdown]
# ### Base de dados Censo COVID-19

# %%
df_censo_base = pd.read_csv('./data/censo/2023-04-10_Censo_Covid19_-_Base_de_Dados.csv', sep=';', encoding='latin-1')
df_censo_base
# Out:
#                  330 - Censo leitos COVID -10/04/2023  \
# 0                                            Hospital
# 1                                                 NaN
# 2                                                 NaN
# 3                                               HUEM
# 4                                                HIZA
# 5                      Complexo Hospital de Clínicas
# 6                           HSC/Instituto de Medicina
# 7                            Hospital São Vicente CIC
# 8                         Hospital São Vicente Centro
# 9                           Hospital Erasto Gaertner
# 10                               HPP leitos Pediatria
# 11  Total de pacientes internados em leitos prefer...
#
#                                            Unnamed: 1  \
# 0   Casos suspeitos e provaveis  ENF adulto e pedi...
# 1                                                 NaN
# 2                                                 NaN
# ...

# %% [markdown]
# ## Doações de Bens e Serviços COVID-19
#
# Relatório contendo as informações sobre as doações de bens e serviços disponibilizadas ao município de Curitiba para o enfrentamento da pandemia COVID-19.

# %% [markdown]
# ### Dicionário de dados de doações de bens e serviços COVID-19

# %%
df_doacoes_dic = pd.read_csv('./data/doacoes/2023-04-01_Doacoes_Bens_Servicos_Covid_19_-_Dicionario_de_Dados.csv', sep=';', encoding='latin-1')
df_doacoes_dic
# Out:
#                        Campo  \
# 0                      Órgão
# 1                     Objeto
# 2                     Doador
# 3                   CNPJ/CPF
# 4                  Protocolo
# 5                 Quantidade
# 6          Unidade de Medida
# 7  Local de Execução/Entrega
# 8        Data do Recebimento
# 9    Destinação / Finalidade
#
#                                            Descrição Tipo de Dado Tamanho
# 0  Secretaria ou ente responsável pelo recebiment...      VARCHAR      10
# 1  São bens e serviços cujos padrões de desempenh...      VARCHAR     500
# 2  Particulares pessoas físicas ou jurídicas, des...      VARCHAR      50
# 3  Número sequencial do particular (pessoa física...      VARCHAR      18
# 4  Conjunto de documentos oficialmente reunidos e...      VARCHAR      40
# 5  Relação numérica que expressa a quantia necess...      NUMERIC    18,2
# 6  Unidade de medida referente a quantidade do ob...      VARCHAR      40
# ...

# %% [markdown]
# ### Base de dados de doações de bens e serviços COVID-19

# %%
df_doacoes_base = pd.read_csv('./data/doacoes/2021-05-10_Doacoes_Bens_Servicos_Covid_19_-_Base_de_Dados.csv', sep=';', encoding='latin-1')
df_doacoes_base
# Out:
#          ÓRGÃO                                             OBJETO  \
# 0   SMAP                            Máscaras em tecido (unidades)
# 1   FAS                                            Cestas Básicas
# 2   FAS                                                    Leites
# 3   FAS                                         Sacolas de roupas
# 4   FAS                                         Sacolas de roupas
# ..         ...                                                ...
# 74  FMS                             Doação de protetores faciais.
# 75  SMAP        Termo doação, sem encargos, pela DOADORA, de 2...
# 76  SMAP        Termo de doação sem encargos, pela DOADORA, à ...
# 77  SMAP                   Chapas PETG medindo 0,50x1220x2440 mm.
# 78  SMAP           Álcool em gel 70% INPM Flip top 500 ml Ecolar.
#
#                                                DOADOR          CNPJ / CPF  \
# 0                    ESTAMPARIA TÊXTIL DE IDEIAS LTDA  13.123.060/0001-43
# ...

# %% [markdown]
# ## Licitações e Contratações COVID-19
#
# Relatório contendo as informações sobre as compras e contratações, com o detalhamento dos gastos públicos durante voltados a situação de pandemia do COVID-19.

# %% [markdown]
# ### Dicionário de dados de licitações e contratações COVID-19

# %%
df_licitacoes_dic = pd.read_csv('./data/licitacoes/2023-04-01_Licitacoes_Contratacoes_Covid_Dados_Basicos_-_Dicionario_de_Dados.csv', sep=';', encoding='latin-1')
df_licitacoes_dic
# Out:
#     Unnamed: 0                           Campo  \
# 0            1                           Órgão
# 1            2              Número do Processo
# 2            3                      Modalidade
# 3            4                          Objeto
# 4            5              Valor Total/Global
# 5            6       Local de Execução/Entrega
# 6            7             Data Diário Oficial
# 7            8                       Protocolo
# 8           10  Início da vigência do contrato
# 9           10     Fim da Vigência do Contrato
# 10          11                        Situação
#
#                                             Descrição Tipo de Dado  Tamanho
# 0   Secretaria ou ente responsável pela realização...      varchar       10
# 1   Numeração sequencial do procedimento licitatório.      varchar       20
# 2                                Forma de Contratação      varchar       50
# 3   São bens e serviços cujos padrões de desempenh...         text       16
# ...

# %% [markdown]
# ### Base de dados de licitações e contratações COVID-19

# %%
df_licitacoes_base = pd.read_csv('./data/licitacoes/2023-04-01_Licitacoes_Contratacoes_Covid_Dados_Basicos_-_Base_de_Dados.csv', sep=';', encoding='latin-1')
df_licitacoes_base
# Out:
#           Órgão Número do Processo                    Modalidade  \
# 0    FMS                 IN 4/2018  Inexigibilidade de Licitação
# 1    SEPLAD            PE 126/2018             PREGÃO ELETRÔNICO
# 2    FMS                PE 98/2018             PREGÃO ELETRÔNICO
# 3    FMS                PE 99/2018             PREGÃO ELETRÔNICO
# 4    FMS                IN 19/2018  Inexigibilidade de Licitação
# ..          ...                ...                           ...
# 816  FMS                IN 20/2022  Inexigibilidade de Licitação
# 817  FMS                IN 22/2022  Inexigibilidade de Licitação
# 818  FMS                PE 93/2022             PREGÃO ELETRÔNICO
# 819  FMS               PE 103/2022             PREGÃO ELETRÔNICO
# 820  FMS               DT 199/2022   Dispensa de Licitação - TCE
#
#                                                 Objeto Valor Total/Global  \
# 0    CREDENCIAMENTO DE SERVIÇO COMPLEMENTAR AO SIST...   R$ 31.451.283,48
# ...

# %% [markdown]
# ### Dicionário de dados de empenhos COVID-19

# %%
df_empenhos_dic = pd.read_csv('./data/licitacoes/2023-04-01_Licitacoes_Contratacoes_Covid_Empenhos_-_Dicionario_de_Dados.csv', sep=';', encoding='latin-1')
df_empenhos_dic
# Out:
#                     Campo                                          Descrição  \
# 0                   Órgão  Secretaria ou ente responsável pela realização...
# 1      Número do Processo  Numeração sequencial do procedimento licitatório.
# 2              Modalidade                               Forma de Contratação
# 3      Número do Contrato  Número sequencial de todo e qualquer ajuste en...
# 4          Número Empenho  Número sequencial de documento utilizado para ...
# 5   Contratado/Fornecedor  Pessoa física ou jurídica signatária de instru...
# 6                CNPJ/CPF  Número sequencial do fornecedor/contratado, re...
# 7         Valor Empenhado  Consiste na reserva de dotação orçamentária pa...
# 8         Valor Liquidado  Valor verificado do direito adquirido pelo con...
# 9           Valor Anulado  São despesas empenhadas de exercícios financei...
# 10             Valor Pago      Valor efetivamente recebido pelo contratado.
# ...

# %% [markdown]
# ### Base de dados de empenhos COVID-19

# %%
df_empenhos_base = pd.read_csv('./data/licitacoes/2023-04-01_Licitacoes_Contratacoes_Covid_Empenhos_-_Base_de_Dados.csv', sep=';', encoding='latin-1')
df_empenhos_base
# Out:
#             Órgão Número do Processo                    Modalidade  \
# 0      FMS                 IN 4/2018  Inexigibilidade de Licitação
# 1      FMS                 IN 4/2018  Inexigibilidade de Licitação
# 2      FMS                 IN 4/2018  Inexigibilidade de Licitação
# 3      FMS                 IN 4/2018  Inexigibilidade de Licitação
# 4      FMS                 IN 4/2018  Inexigibilidade de Licitação
# ...           ...                ...                           ...
# 20228  FMS                PE 93/2022             PREGÃO ELETRÔNICO
# 20229  FMS                PE 93/2022             PREGÃO ELETRÔNICO
# 20230  FMS               PE 103/2022             PREGÃO ELETRÔNICO
# 20231  FMS               PE 103/2022             PREGÃO ELETRÔNICO
# 20232  FMS               DT 199/2022   Dispensa de Licitação - TCE
#
#        Número do Contrato  Número do Empenho  \
# 0                   518.0                 95
# 1                   519.0                 96
# ...

# %% [markdown]
# ### Dicionário de itens processo COVID-19

# %%
df_itens_dic = pd.read_csv('./data/licitacoes/2023-04-01_Licitacoes_Contratacoes_Covid_Itens_Processo_-_Dicionario_de_Dados.csv', sep=';', encoding='latin-1')
df_itens_dic
# Out:
#                              Campo  \
# 0                            Órgão
# 1               Número do Processo
# 2                       Modalidade
# 3                             Item
# 4                       Quantidade
# 5                Unidade de Medida
# 6            Contratado/Fornecedor
# 7                         CNPJ/CPF
# 8               Número do Contrato
# 9   Inicio da Vigência do Contrato
# 10     Fim da Vigência do Contrato
# 11                  Valor Unitário
# 12              Valor Total/Global
#
#                                             Descrição Tipo de Dado  Tamanho
# 0   Secretaria ou ente responsável pela realização...      varchar       10
# 1   Numeração sequencial do procedimento licitatório.          int        4
# 2                                Forma de Contratação      varchar       50
# 3                     Descrição do objeto contratado       varchar      121
# 4   Relação numérica que expressa a quantia necess...      decimal        9
# ...

# %% [markdown]
# ### Base de dados de itens processo COVID-19

# %%
df_processo_base = pd.read_csv('./data/licitacoes/2023-04-01_Licitacoes_Contratacoes_Covid_Itens_Processo_-_Base_de_Dados.csv', sep=';', encoding='latin-1')
df_processo_base
# Out:
#            Órgão Número do Processo                    Modalidade  \
# 0     FMS                 IN 4/2018  Inexigibilidade de Licitação
# 1     FMS                 IN 4/2018  Inexigibilidade de Licitação
# 2     FMS                 IN 4/2018  Inexigibilidade de Licitação
# 3     FMS                 IN 4/2018  Inexigibilidade de Licitação
# 4     FMS                 IN 4/2018  Inexigibilidade de Licitação
# ...          ...                ...                           ...
# 7053  FMS                PE 93/2022             PREGÃO ELETRÔNICO
# 7054  FMS                PE 93/2022             PREGÃO ELETRÔNICO
# 7055  FMS               PE 103/2022             PREGÃO ELETRÔNICO
# 7056  FMS               PE 103/2022             PREGÃO ELETRÔNICO
# 7057  FMS               DT 199/2022   Dispensa de Licitação - TCE
#
#                                                    Item  Quantidade  \
# 0     CREDENCIAMENTO,  para prestadores de serviços ...         1.0
# ...
